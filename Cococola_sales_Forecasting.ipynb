# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_excel("/content/CocaCola_Sales_Rawdata.xlsx")

# %%
dataset
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# ...

# %%
dataset.isnull().any()
# Out:
# Quarter    False
# Sales      False
# dtype: bool

# %%
dataset.describe()
# Out:
#              Sales
# count    42.000000
# mean   2994.353308
# std     977.930896
# min    1547.818996
# 25%    2159.714247
# 50%    2782.376999
# 75%    3609.250000
# max    5253.000000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Quarter  42 non-null     object
#  1   Sales    42 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 800.0+ bytes

# %%
dataset.skew()
# Out:
# <ipython-input-7-8035be43cde7>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.skew()
# Sales    0.630162
# dtype: float64

# %%
dataset.kurt()
# Out:
# <ipython-input-8-ad8cfc4feed4>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset.kurt()
# Sales   -0.584372
# dtype: float64

# %%
dataset
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# ...

# %%
dataset
# Out:
#    Quarter        Sales
# 0    Q1_86  1734.827000
# 1    Q2_86  2244.960999
# 2    Q3_86  2533.804993
# 3    Q4_86  2154.962997
# 4    Q1_87  1547.818996
# 5    Q2_87  2104.411995
# 6    Q3_87  2014.362999
# 7    Q4_87  1991.746998
# 8    Q1_88  1869.049999
# 9    Q2_88  2313.631996
# 10   Q3_88  2128.320000
# 11   Q4_88  2026.828999
# 12   Q1_89  1910.603996
# 13   Q2_89  2331.164993
# 14   Q3_89  2206.549995
# 15   Q4_89  2173.967995
# 16   Q1_90  2148.278000
# 17   Q2_90  2739.307999
# 18   Q3_90  2792.753998
# 19   Q4_90  2556.009995
# 20   Q1_91  2480.973999
# 21   Q2_91  3039.522995
# 22   Q3_91  3172.115997
# 23   Q4_91  2879.000999
# 24   Q1_92  2772.000000
# 25   Q2_92  3550.000000
# 26   Q3_92  3508.000000
# 27   Q4_92  3243.859993
# 28   Q1_93  3056.000000
# 29   Q2_93  3899.000000
# 30   Q3_93  3629.000000
# 31   Q4_93  3373.000000
# 32   Q1_94  3352.000000
# 33   Q2_94  4342.000000
# 34   Q3_94  4461.000000
# 35   Q4_94  4017.000000
# 36   Q1_95  3854.000000
# ...

# %%
dataset['Quarter_year']=dataset['Quarter'].str.split('_').apply(lambda x:' 19'.join(x[:]))
dataset
# Out:
#    Quarter        Sales Quarter_year
# 0    Q1_86  1734.827000      Q1 1986
# 1    Q2_86  2244.960999      Q2 1986
# 2    Q3_86  2533.804993      Q3 1986
# 3    Q4_86  2154.962997      Q4 1986
# 4    Q1_87  1547.818996      Q1 1987
# 5    Q2_87  2104.411995      Q2 1987
# 6    Q3_87  2014.362999      Q3 1987
# 7    Q4_87  1991.746998      Q4 1987
# 8    Q1_88  1869.049999      Q1 1988
# 9    Q2_88  2313.631996      Q2 1988
# 10   Q3_88  2128.320000      Q3 1988
# 11   Q4_88  2026.828999      Q4 1988
# 12   Q1_89  1910.603996      Q1 1989
# 13   Q2_89  2331.164993      Q2 1989
# 14   Q3_89  2206.549995      Q3 1989
# 15   Q4_89  2173.967995      Q4 1989
# 16   Q1_90  2148.278000      Q1 1990
# 17   Q2_90  2739.307999      Q2 1990
# 18   Q3_90  2792.753998      Q3 1990
# 19   Q4_90  2556.009995      Q4 1990
# 20   Q1_91  2480.973999      Q1 1991
# 21   Q2_91  3039.522995      Q2 1991
# 22   Q3_91  3172.115997      Q3 1991
# 23   Q4_91  2879.000999      Q4 1991
# ...

# %%
dataset['Date']=(pd.to_datetime(dataset['Quarter_year'].str.split(' ').apply(lambda x: ''.join(x[::-1])),dayfirst=True))
dataset
# Out:
#    Quarter        Sales Quarter_year       Date
# 0    Q1_86  1734.827000      Q1 1986 1986-01-01
# 1    Q2_86  2244.960999      Q2 1986 1986-04-01
# 2    Q3_86  2533.804993      Q3 1986 1986-07-01
# 3    Q4_86  2154.962997      Q4 1986 1986-10-01
# 4    Q1_87  1547.818996      Q1 1987 1987-01-01
# 5    Q2_87  2104.411995      Q2 1987 1987-04-01
# 6    Q3_87  2014.362999      Q3 1987 1987-07-01
# 7    Q4_87  1991.746998      Q4 1987 1987-10-01
# 8    Q1_88  1869.049999      Q1 1988 1988-01-01
# 9    Q2_88  2313.631996      Q2 1988 1988-04-01
# 10   Q3_88  2128.320000      Q3 1988 1988-07-01
# 11   Q4_88  2026.828999      Q4 1988 1988-10-01
# 12   Q1_89  1910.603996      Q1 1989 1989-01-01
# 13   Q2_89  2331.164993      Q2 1989 1989-04-01
# 14   Q3_89  2206.549995      Q3 1989 1989-07-01
# 15   Q4_89  2173.967995      Q4 1989 1989-10-01
# 16   Q1_90  2148.278000      Q1 1990 1990-01-01
# 17   Q2_90  2739.307999      Q2 1990 1990-04-01
# 18   Q3_90  2792.753998      Q3 1990 1990-07-01
# ...

# %%
dataset['Quarters']=0
for i in range(42):
  n=dataset['Quarter'][i]
  dataset['Quarters'][i]=n[0:2]
dataset
# Out:
# <ipython-input-13-6fadeafe33b7>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['Quarters'][i]=n[0:2]
#    Quarter        Sales Quarter_year       Date Quarters
# 0    Q1_86  1734.827000      Q1 1986 1986-01-01       Q1
# 1    Q2_86  2244.960999      Q2 1986 1986-04-01       Q2
# 2    Q3_86  2533.804993      Q3 1986 1986-07-01       Q3
# 3    Q4_86  2154.962997      Q4 1986 1986-10-01       Q4
# 4    Q1_87  1547.818996      Q1 1987 1987-01-01       Q1
# 5    Q2_87  2104.411995      Q2 1987 1987-04-01       Q2
# 6    Q3_87  2014.362999      Q3 1987 1987-07-01       Q3
# 7    Q4_87  1991.746998      Q4 1987 1987-10-01       Q4
# 8    Q1_88  1869.049999      Q1 1988 1988-01-01       Q1
# 9    Q2_88  2313.631996      Q2 1988 1988-04-01       Q2
# ...

# %% [markdown]
# ###Creating Dummy Variables

# %%
dummy=pd.DataFrame(pd.get_dummies(dataset['Quarters']))
dataset1=pd.concat((dataset,dummy),axis=1)
dataset1
# Out:
#    Quarter        Sales Quarter_year       Date Quarters  Q1  Q2  Q3  Q4
# 0    Q1_86  1734.827000      Q1 1986 1986-01-01       Q1   1   0   0   0
# 1    Q2_86  2244.960999      Q2 1986 1986-04-01       Q2   0   1   0   0
# 2    Q3_86  2533.804993      Q3 1986 1986-07-01       Q3   0   0   1   0
# 3    Q4_86  2154.962997      Q4 1986 1986-10-01       Q4   0   0   0   1
# 4    Q1_87  1547.818996      Q1 1987 1987-01-01       Q1   1   0   0   0
# 5    Q2_87  2104.411995      Q2 1987 1987-04-01       Q2   0   1   0   0
# 6    Q3_87  2014.362999      Q3 1987 1987-07-01       Q3   0   0   1   0
# 7    Q4_87  1991.746998      Q4 1987 1987-10-01       Q4   0   0   0   1
# 8    Q1_88  1869.049999      Q1 1988 1988-01-01       Q1   1   0   0   0
# 9    Q2_88  2313.631996      Q2 1988 1988-04-01       Q2   0   1   0   0
# 10   Q3_88  2128.320000      Q3 1988 1988-07-01       Q3   0   0   1   0
# 11   Q4_88  2026.828999      Q4 1988 1988-10-01       Q4   0   0   0   1
# ...

# %%
dataset1.drop(['Quarter','Quarter_year'],axis=1,inplace=True)
dataset1
# Out:
#           Sales       Date Quarters  Q1  Q2  Q3  Q4
# 0   1734.827000 1986-01-01       Q1   1   0   0   0
# 1   2244.960999 1986-04-01       Q2   0   1   0   0
# 2   2533.804993 1986-07-01       Q3   0   0   1   0
# 3   2154.962997 1986-10-01       Q4   0   0   0   1
# 4   1547.818996 1987-01-01       Q1   1   0   0   0
# 5   2104.411995 1987-04-01       Q2   0   1   0   0
# 6   2014.362999 1987-07-01       Q3   0   0   1   0
# 7   1991.746998 1987-10-01       Q4   0   0   0   1
# 8   1869.049999 1988-01-01       Q1   1   0   0   0
# 9   2313.631996 1988-04-01       Q2   0   1   0   0
# 10  2128.320000 1988-07-01       Q3   0   0   1   0
# 11  2026.828999 1988-10-01       Q4   0   0   0   1
# 12  1910.603996 1989-01-01       Q1   1   0   0   0
# 13  2331.164993 1989-04-01       Q2   0   1   0   0
# 14  2206.549995 1989-07-01       Q3   0   0   1   0
# 15  2173.967995 1989-10-01       Q4   0   0   0   1
# 16  2148.278000 1990-01-01       Q1   1   0   0   0
# ...

# %%
dataset1.set_index('Date',inplace=True)
dataset1
# Out:
#                   Sales Quarters  Q1  Q2  Q3  Q4
# Date
# 1986-01-01  1734.827000       Q1   1   0   0   0
# 1986-04-01  2244.960999       Q2   0   1   0   0
# 1986-07-01  2533.804993       Q3   0   0   1   0
# 1986-10-01  2154.962997       Q4   0   0   0   1
# 1987-01-01  1547.818996       Q1   1   0   0   0
# 1987-04-01  2104.411995       Q2   0   1   0   0
# 1987-07-01  2014.362999       Q3   0   0   1   0
# 1987-10-01  1991.746998       Q4   0   0   0   1
# 1988-01-01  1869.049999       Q1   1   0   0   0
# 1988-04-01  2313.631996       Q2   0   1   0   0
# 1988-07-01  2128.320000       Q3   0   0   1   0
# 1988-10-01  2026.828999       Q4   0   0   0   1
# 1989-01-01  1910.603996       Q1   1   0   0   0
# 1989-04-01  2331.164993       Q2   0   1   0   0
# 1989-07-01  2206.549995       Q3   0   0   1   0
# 1989-10-01  2173.967995       Q4   0   0   0   1
# 1990-01-01  2148.278000       Q1   1   0   0   0
# 1990-04-01  2739.307999       Q2   0   1   0   0
# ...

# %%
plt.figure(figsize=(15,5))
plt.plot(dataset1['Sales'],marker='o')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x="Quarters",y="Sales",data=dataset)
plt.show()

# %%
dataset['Year']=dataset.Date.dt.strftime("%Y")

# %%
dataset
# Out:
#    Quarter        Sales Quarter_year       Date Quarters  Year
# 0    Q1_86  1734.827000      Q1 1986 1986-01-01       Q1  1986
# 1    Q2_86  2244.960999      Q2 1986 1986-04-01       Q2  1986
# 2    Q3_86  2533.804993      Q3 1986 1986-07-01       Q3  1986
# 3    Q4_86  2154.962997      Q4 1986 1986-10-01       Q4  1986
# 4    Q1_87  1547.818996      Q1 1987 1987-01-01       Q1  1987
# 5    Q2_87  2104.411995      Q2 1987 1987-04-01       Q2  1987
# 6    Q3_87  2014.362999      Q3 1987 1987-07-01       Q3  1987
# 7    Q4_87  1991.746998      Q4 1987 1987-10-01       Q4  1987
# 8    Q1_88  1869.049999      Q1 1988 1988-01-01       Q1  1988
# 9    Q2_88  2313.631996      Q2 1988 1988-04-01       Q2  1988
# 10   Q3_88  2128.320000      Q3 1988 1988-07-01       Q3  1988
# 11   Q4_88  2026.828999      Q4 1988 1988-10-01       Q4  1988
# 12   Q1_89  1910.603996      Q1 1989 1989-01-01       Q1  1989
# 13   Q2_89  2331.164993      Q2 1989 1989-04-01       Q2  1989
# ...

# %%
plt.figure(figsize=(15,5))
sns.lineplot(x="Year",y="Sales",data=dataset)
plt.show()

# %%
plt.figure(figsize=(15,5))
dataset.Sales.plot(kind='kde')
plt.show()

# %%
plt.figure(figsize=(15,5))
dataset.Sales.hist()
plt.show()

# %%
from pandas.plotting import lag_plot
for i in [1,4,8,16,32,40]:
  lag_plot(dataset['Sales'],lag=i)
  plt.title(f'Lag {i}')
  plt.show()

# %% [markdown]
# ###Moving Average

# %%
plt.figure(figsize=(15,5))
dataset.Sales.plot(label='org')
for i in range(4,13,4):
  dataset['Sales'].rolling(i).mean().plot(label=str(i))
plt.legend(loc="best")
plt.show()

# %%
plt.figure(figsize=(15,5))
dataset.Sales.plot(label="Org")
plt.title("Original Series")
plt.show()
for i in range(2,9,2):
  plt.figure(figsize=(15,5))
  dataset['Sales'].rolling(i).mean().plot(label=str(i))
  plt.title(f'Moving Average {i}')
  plt.legend(loc='best')
  plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose_ts_add=seasonal_decompose(dataset['Sales'],period=4)
plt.figure(figsize=(15,5))
decompose_ts_add.plot()

# %% [markdown]
# ###ACF AND PACF PLOTS

# %%
import statsmodels.graphics.tsaplots as tsa_plots
tsa_plots.plot_acf(dataset['Sales'],lags=40)
plt.title("ACF")
plt.show()

# %%
tsa_plots.plot_pacf(dataset['Sales'],lags=20)
plt.title("PACF")
plt.show()

# %%
dataset1
# Out:
#                   Sales Quarters  Q1  Q2  Q3  Q4
# Date
# 1986-01-01  1734.827000       Q1   1   0   0   0
# 1986-04-01  2244.960999       Q2   0   1   0   0
# 1986-07-01  2533.804993       Q3   0   0   1   0
# 1986-10-01  2154.962997       Q4   0   0   0   1
# 1987-01-01  1547.818996       Q1   1   0   0   0
# 1987-04-01  2104.411995       Q2   0   1   0   0
# 1987-07-01  2014.362999       Q3   0   0   1   0
# 1987-10-01  1991.746998       Q4   0   0   0   1
# 1988-01-01  1869.049999       Q1   1   0   0   0
# 1988-04-01  2313.631996       Q2   0   1   0   0
# 1988-07-01  2128.320000       Q3   0   0   1   0
# 1988-10-01  2026.828999       Q4   0   0   0   1
# 1989-01-01  1910.603996       Q1   1   0   0   0
# 1989-04-01  2331.164993       Q2   0   1   0   0
# 1989-07-01  2206.549995       Q3   0   0   1   0
# 1989-10-01  2173.967995       Q4   0   0   0   1
# 1990-01-01  2148.278000       Q1   1   0   0   0
# 1990-04-01  2739.307999       Q2   0   1   0   0
# ...

# %%
upsampled_month=dataset1.drop(['Quarters','Q1','Q2','Q3','Q4'],axis=1)
upsampled_month=upsampled_month.resample('M').mean()
print(upsampled_month)
# Out:
#                   Sales
# Date
# 1986-01-31  1734.827000
# 1986-02-28          NaN
# 1986-03-31          NaN
# 1986-04-30  2244.960999
# 1986-05-31          NaN
# ...                 ...
# 1995-12-31          NaN
# 1996-01-31  4194.000000
# 1996-02-29          NaN
# 1996-03-31          NaN
# 1996-04-30  5253.000000
#
# [124 rows x 1 columns]

# %%
interpolate=upsampled_month.interpolate(method='linear')
print(interpolate.head(13))
interpolate.plot()
plt.show()
# Out:
#                   Sales
# Date
# 1986-01-31  1734.827000
# 1986-02-28  1904.871666
# 1986-03-31  2074.916332
# 1986-04-30  2244.960999
# 1986-05-31  2341.242330
# 1986-06-30  2437.523661
# 1986-07-31  2533.804993
# 1986-08-31  2407.524328
# 1986-09-30  2281.243663
# 1986-10-31  2154.962997
# 1986-11-30  1952.581664
# 1986-12-31  1750.200330
# 1987-01-31  1547.818996

# %%
interpolate
# Out:
#                   Sales
# Date
# 1986-01-31  1734.827000
# 1986-02-28  1904.871666
# 1986-03-31  2074.916332
# 1986-04-30  2244.960999
# 1986-05-31  2341.242330
# ...                 ...
# 1995-12-31  4240.333333
# 1996-01-31  4194.000000
# 1996-02-29  4547.000000
# 1996-03-31  4900.000000
# 1996-04-30  5253.000000
#
# [124 rows x 1 columns]

# %%
plt.figure(figsize=(15,5))
interpolate.Sales.plot(label="org")
plt.title("Original Series")
for i in range(2,13,2):
  plt.figure(figsize=(15,5))
  interpolate.Sales.rolling(i).mean().plot(label=str(i))
  plt.title(f'Moving average {i}')
  plt.legend(loc="best")
  plt.show()

# %%
decompose_ts_add=seasonal_decompose(interpolate.Sales,period=12,model="additive")
decompose_ts_add.plot()
plt.show()

# %%
decompose_ts_add=seasonal_decompose(interpolate.Sales,period=12,model="multiplication")
decompose_ts_add.plot()
plt.show()

# %%
interpolate
# Out:
#                   Sales
# Date
# 1986-01-31  1734.827000
# 1986-02-28  1904.871666
# 1986-03-31  2074.916332
# 1986-04-30  2244.960999
# 1986-05-31  2341.242330
# ...                 ...
# 1995-12-31  4240.333333
# 1996-01-31  4194.000000
# 1996-02-29  4547.000000
# 1996-03-31  4900.000000
# 1996-04-30  5253.000000
#
# [124 rows x 1 columns]

# %%
train=interpolate[:100]
test=interpolate[100:]

# %%
train
# Out:
#                   Sales
# Date
# 1986-01-31  1734.827000
# 1986-02-28  1904.871666
# 1986-03-31  2074.916332
# 1986-04-30  2244.960999
# 1986-05-31  2341.242330
# ...                 ...
# 1993-12-31  3359.000000
# 1994-01-31  3352.000000
# 1994-02-28  3682.000000
# 1994-03-31  4012.000000
# 1994-04-30  4342.000000
#
# [100 rows x 1 columns]

# %%
test
# Out:
#                   Sales
# Date
# 1994-05-31  4381.666667
# 1994-06-30  4421.333333
# 1994-07-31  4461.000000
# 1994-08-31  4313.000000
# 1994-09-30  4165.000000
# 1994-10-31  4017.000000
# 1994-11-30  3962.666667
# 1994-12-31  3908.333333
# 1995-01-31  3854.000000
# 1995-02-28  4214.666667
# 1995-03-31  4575.333333
# 1995-04-30  4936.000000
# 1995-05-31  4922.333333
# 1995-06-30  4908.666667
# 1995-07-31  4895.000000
# 1995-08-31  4707.666667
# 1995-09-30  4520.333333
# 1995-10-31  4333.000000
# 1995-11-30  4286.666667
# 1995-12-31  4240.333333
# 1996-01-31  4194.000000
# 1996-02-29  4547.000000
# 1996-03-31  4900.000000
# 1996-04-30  5253.000000

# %%
plt.figure(figsize=(15,5))
plt.plot(train,label="Train Data")
plt.plot(test,label="Test Data")
plt.legend()
plt.show()

# %%
def MAPE(pred,org):
  temp=np.abs((pred-org)/org)*100
  return np.mean(temp)

# %% [markdown]
# ###Simple Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from math import sqrt
from sklearn.metrics import mean_squared_error
ses_model=SimpleExpSmoothing(train['Sales']).fit(optimized=True)
test_ses=ses_model.forecast(24)
train_ses=ses_model.fittedvalues
test_rmse_ses=sqrt(mean_squared_error(test_ses,test.Sales))
train_rmse_ses=sqrt(mean_squared_error(train_ses,train.Sales))
mape_ses=MAPE(test_ses,test.Sales)
print(f'Test RMSE values {test_rmse_ses}')
print(f'Train RMSE values {train_rmse_ses}')
print(f'Test MAPE values {mape_ses}')
# Out:
# Test RMSE values 381.95422355078995
# Train RMSE values 129.37951431349904
# Test MAPE values 6.6197194272254025

# %%
plt.figure(figsize=(15,5))
plt.plot(train,label="train")
plt.plot(test,label="test")
plt.plot(test_ses,label="Simple Exponential Smoothing")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ###Double Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import Holt
des_model=Holt(train.Sales).fit(optimized=True)
test_des=des_model.forecast(24)
train_des=des_model.fittedvalues
test_rmse_des=sqrt(mean_squared_error(test_des,test.Sales))
train_rmse_des=sqrt(mean_squared_error(train_des,train.Sales))
mape_des=MAPE(test_des,test.Sales)
print(f'Test RMSE values {test_rmse_des}')
print(f'Train RMSE values {train_rmse_des}')
print(f'Test MAPE values {mape_des}')
# Out:
# Test RMSE values 4549.83259387513
# Train RMSE values 108.70855330066725
# Test MAPE values 89.4931606588976

# %%
plt.figure(figsize=(15,4))
plt.plot(train,label="Train")
plt.plot(test,label="test")
plt.plot(test_ses,label="Simple Exponential")
plt.plot(test_des,label="Double Exponential")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ###Holts Winter Exponential Smoothing with Additive Seasonality and Additive Trend

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
texp_add_add_model=ExponentialSmoothing(train,seasonal="add",trend="add",seasonal_periods=12).fit(optimized=True)
test_texp_add_add=texp_add_add_model.forecast(24)
train_texp_add_add=texp_add_add_model.fittedvalues
test_rmse_texp_add_add=sqrt(mean_squared_error(test_texp_add_add,test.Sales))
train_rmse_texp_add_add=sqrt(mean_squared_error(train_texp_add_add,train.Sales))
mape_texp_add_add=MAPE(test_texp_add_add,test.Sales)
print(f'Test RMSE {test_rmse_texp_add_add}')
print(f'Train RMSE {train_rmse_texp_add_add}')
print(f'MAPE is {mape_texp_add_add}')
# Out:
# Test RMSE 1828.4767720554398
# Train RMSE 44.2653652251861
# MAPE is 35.69571274324909

# %%
plt.figure(figsize=(15,5))
plt.plot(train,label="Train")
plt.plot(test,label="Test")
plt.plot(test_ses,label="Simple Exponential")
plt.plot(test_des,label="Double Exponential")
plt.plot(test_texp_add_add,label="Triple Exponential With additive seasonality and additive trend")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ###Holt Winters Exponential Smoothing with Multiplicative Seasonality and additive trend

# %%
texp_mul_add_model=ExponentialSmoothing(train,seasonal="mul",trend="add",seasonal_periods=12).fit(optimized=True)
test_texp_mul_add=texp_mul_add_model.forecast(24)
train_texp_mul_add=texp_mul_add_model.fittedvalues
test_rmse_texp_mul_add=sqrt(mean_squared_error(test_texp_mul_add,test.Sales))
train_rmse_texp_mul_add=sqrt(mean_squared_error(train_texp_mul_add,train.Sales))
mape_texp_mul_add=MAPE(test_texp_mul_add,test.Sales)
print(f'Test RMSE values {test_rmse_texp_mul_add}')
print(f'Train RMSE values {train_rmse_texp_mul_add}')
print(f'MAPE is {mape_texp_mul_add}')
# Out:
# Test RMSE values 78.73325826552858
# Train RMSE values 50.223974444654
# MAPE is 1.487268775553493

# %%
plt.figure(figsize=(15,5))
plt.plot(train,label="Train")
plt.plot(test,label="Test")
plt.plot(test_ses,label="Simple Exponential Smoothing")
plt.plot(test_des,label="Double Exponential Smoothing")
plt.plot(test_texp_add_add,label="Triple Exponential Smoothing with Additive Seasonality and additive Trend")
plt.plot(test_texp_mul_add,label="Triple Exponential Smoothing with Multiplicative Seasonality and additive Trend")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ###Holt Winters Exponential Smoothing with Additive Seasonality and Multiplicative Trend

# %%
texp_add_mul_model=ExponentialSmoothing(train,seasonal="add",trend="mul",seasonal_periods=12).fit(optimized=True,smoothing_level=0.5)
test_texp_add_mul=texp_add_mul_model.forecast(24)
train_texp_add_mul=texp_add_mul_model.fittedvalues
test_rmse_texp_add_mul=sqrt(mean_squared_error(test_texp_add_mul,test))
train_rmse_texp_add_mul=sqrt(mean_squared_error(train_texp_add_mul,train))
mape_texp_add_mul=MAPE(test_texp_add_mul,test.Sales)
print(f'Test RMSE is {test_rmse_texp_add_mul}')
print(f'Train RMSE is {train_rmse_texp_add_mul}')
print(f'MAPE is {mape_texp_add_mul}')
# Out:
# Test RMSE is 291.5596777367078
# Train RMSE is 90.18926414392342
# MAPE is 5.439766693068006
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/holtwinters/model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err

# %%
plt.figure(figsize=(15,5))
plt.plot(train,label="Train")
plt.plot(test,label="Test")
plt.plot(test_ses,label="Simple Exponential Smoothing")
plt.plot(test_des,label="Double Exponential Smoothing")
plt.plot(test_texp_add_add,label="Triple Exponential Smoothing with Additive Seasonality and additive Trend")
plt.plot(test_texp_mul_add,label="Triple Exponential Smoothing with Multiplicative Seasonality and additive Trend")
plt.plot(test_texp_add_mul,label="Triple Exponential Smoothing with Additive Seasonality and Multiplicative Trend")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ###Holt Winters Exponential Smoothing with Multiplicative Seasonality and Multiplicative trend

# %%
texp_mul_mul_model=ExponentialSmoothing(train,seasonal="mul",trend="mul",seasonal_periods=12).fit(optimized=True)
test_texp_mul_mul=texp_mul_mul_model.forecast(24)
train_texp_mul_mul=texp_mul_mul_model.fittedvalues
test_rmse_texp_mul_mul=sqrt(mean_squared_error(test_texp_mul_mul,test))
train_rmse_texp_mul_mul=sqrt(mean_squared_error(train_texp_mul_mul,train))
mape_texp_mul_mul=MAPE(test_texp_mul_mul,test.Sales)
print(f'Test RMSE is {test_rmse_texp_mul_mul}')
print(f'Train RMSE is {train_rmse_texp_mul_mul}')
print(f'MAPE is {mape_texp_mul_mul}')
# Out:
# Test RMSE is 101.65134880354205
# Train RMSE is 49.43910507382248
# MAPE is 1.8078233252851952
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/holtwinters/model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err

# %%
plt.figure(figsize=(15,5))
plt.plot(train,label="Train")
plt.plot(test,label="Test")
plt.plot(test_ses,label="Simple Exponential Smoothing")
plt.plot(test_des,label="Double Exponential Smoothing")
plt.plot(test_texp_add_add,label="Triple Exponential Smoothing with Additive Seasonality and additive Trend")
plt.plot(test_texp_mul_add,label="Triple Exponential Smoothing with Multiplicative Seasonality and additive Trend")
plt.plot(test_texp_add_mul,label="Triple Exponential Smoothing with Additive Seasonality and Multiplicative Trend")
plt.plot(test_texp_mul_mul,color="black",label="Triple Exponential Smoothing with Multiplicative Seasonality and Multiplicative Trend")
plt.legend(loc="best")
plt.show()

# %%
Evaluation={"Models":pd.Series(["Simple_Exponential","Double_Exponential","Triple_Exponential_Add","Triple_Exponential_Mul_Add","Triple_Exponential_Add_Mul","Triple_Exponential_Mul_Mul"]),
            "Test_RMSE":pd.Series([test_rmse_ses,test_rmse_des,test_rmse_texp_add_add,test_rmse_texp_mul_add,test_rmse_texp_add_mul,test_rmse_texp_mul_mul]),
            "Train_RMSE":pd.Series([train_rmse_ses,train_rmse_des,train_rmse_texp_add_add,train_rmse_texp_mul_add,train_rmse_texp_add_mul,train_rmse_texp_mul_mul]),
            "MAPE":pd.Series([mape_ses,mape_des,mape_texp_add_add,mape_texp_mul_add,mape_texp_add_mul,mape_texp_mul_mul])
            }
table=pd.DataFrame(Evaluation)
table.sort_values(['Test_RMSE'],inplace=True)
table
# Out:
#                        Models    Test_RMSE  Train_RMSE       MAPE
# 3  Triple_Exponential_Mul_Add    78.733258   50.223974   1.487269
# 5  Triple_Exponential_Mul_Mul   101.651349   49.439105   1.807823
# 4  Triple_Exponential_Add_Mul   291.559678   90.189264   5.439767
# 0          Simple_Exponential   381.954224  129.379514   6.619719
# 2      Triple_Exponential_Add  1828.476772   44.265365  35.695713
# 1          Double_Exponential  4549.832594  108.708553  89.493161

# %%
sns.barplot(x="Test_RMSE",y="Models",data=table)
# Out:
# <Axes: xlabel='Test_RMSE', ylabel='Models'>

# %% [markdown]
# ###ARIMA

# %% [markdown]
# ###Check for Stationarity

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
  movingavg=timeseries.rolling(window=4).mean()
  movingstd=timeseries.rolling(window=4).std()

  orig=plt.plot(timeseries,label="Original")
  mean=plt.plot(movingavg,label="Moving Average")
  plt.legend(loc="best")
  plt.title("Moving Average")
  plt.show()

  dftest=adfuller(timeseries['Sales'],autolag='AIC')
  adfoutput=pd.Series(dftest[:4],index=['Test Statistic','p','No of Lags','No of Obs'])
  for key,val in dftest[4].items():
    adfoutput['Critical value (%s)'%key]=val
  print(adfoutput)

# %%
sales=pd.DataFrame()
sales['Sales']=interpolate[['Sales']]
test_stationarity(sales)
# Out:
# Test Statistic            0.572599
# p                         0.986920
# No of Lags               10.000000
# No of Obs               113.000000
# Critical value (1%)      -3.489590
# Critical value (5%)      -2.887477
# Critical value (10%)     -2.580604
# dtype: float64

# %%
def adftest(series):
  adft=adfuller(series,autolag="AIC")
  labels=['Test Statistic','p-value','no of lags','No of obs']
  out=pd.Series(adft[:4],index=labels)

  if adft[1]<=0.05:
     print("Reject Null Hypothesis")
     print("Data is  Stationary")
  else:
    print("Accept Null Hypothesis")
    print("Data is non Stationary")

# %%
adftest(interpolate.Sales)
# Out:
# Accept Null Hypothesis
# Data is non Stationary

# %% [markdown]
# ###Applying Transformations

# %% [markdown]
# ####1. Square Root

# %%
square_root=pd.DataFrame()
square_root=interpolate[['Sales']]
square_root['Sales']=np.sqrt(square_root.Sales)

plt.plot(square_root.Sales)

# %%
plt.hist(square_root['Sales'])
# Out:
# (array([ 4., 22., 22., 12., 14., 13., 13., 10.,  8.,  6.]),
#  array([39.34233085, 42.65585604, 45.96938123, 49.28290641, 52.5964316 ,
#         55.90995679, 59.22348198, 62.53700717, 65.85053236, 69.16405755,
#         72.47758274]),
#  <BarContainer object of 10 artists>)

# %%
test_stationarity(square_root)
# Out:
# Test Statistic            0.728012
# p                         0.990381
# No of Lags               13.000000
# No of Obs               110.000000
# Critical value (1%)      -3.491245
# Critical value (5%)      -2.888195
# Critical value (10%)     -2.580988
# dtype: float64

# %%
adftest(square_root)
# Out:
# Accept Null Hypothesis
# Data is non Stationary

# %% [markdown]
# ####2. Log Transform

# %%
log_data=pd.DataFrame()

log_data['Sales']=interpolate[['Sales']]
log_data['Sales']=np.log(log_data.Sales)
plt.plot(log_data.Sales)

# %%
plt.hist(log_data.Sales)
# Out:
# (array([ 3.,  9., 26., 13., 14., 12., 17.,  9., 14.,  7.]),
#  array([7.34460212, 7.46679737, 7.58899262, 7.71118787, 7.83338312,
#         7.95557837, 8.07777362, 8.19996887, 8.32216412, 8.44435937,
#         8.56655462]),
#  <BarContainer object of 10 artists>)

# %%
test_stationarity(log_data)
# Out:
# Test Statistic            0.451508
# p                         0.983322
# No of Lags               13.000000
# No of Obs               110.000000
# Critical value (1%)      -3.491245
# Critical value (5%)      -2.888195
# Critical value (10%)     -2.580988
# dtype: float64

# %%
adftest(log_data)
# Out:
# Accept Null Hypothesis
# Data is non Stationary

# %% [markdown]
# ####4. BoxCox transformations

# %%
from scipy.stats import boxcox
boxCox=pd.DataFrame()
boxCox['Sales']=pd.Series(boxcox(interpolate['Sales'],lmbda=0),interpolate.index)
plt.plot(boxCox)

# %%
plt.hist(boxCox)
# Out:
# (array([ 3.,  9., 26., 13., 14., 12., 17.,  9., 14.,  7.]),
#  array([7.34460212, 7.46679737, 7.58899262, 7.71118787, 7.83338312,
#         7.95557837, 8.07777362, 8.19996887, 8.32216412, 8.44435937,
#         8.56655462]),
#  <BarContainer object of 10 artists>)

# %%
test_stationarity(boxCox)
# Out:
# Test Statistic            0.451508
# p                         0.983322
# No of Lags               13.000000
# No of Obs               110.000000
# Critical value (1%)      -3.491245
# Critical value (5%)      -2.888195
# Critical value (10%)     -2.580988
# dtype: float64

# %%
adftest(boxCox)
# Out:
# Accept Null Hypothesis
# Data is non Stationary

# %% [markdown]
# ###Since the data is non stationary we will try differencing the data

# %%
square_root_diff=square_root-square_root.shift()
square_root_diff.dropna(inplace=True)
plt.plot(square_root_diff)

# %%
test_stationarity(square_root_diff)
# Out:
# Test Statistic           -2.802445
# p                         0.057925
# No of Lags               12.000000
# No of Obs               110.000000
# Critical value (1%)      -3.491245
# Critical value (5%)      -2.888195
# Critical value (10%)     -2.580988
# dtype: float64

# %%
adftest(square_root_diff)
# Out:
# Accept Null Hypothesis
# Data is non Stationary

# %%
log_data_diff=log_data-log_data.shift()
log_data_diff.dropna(inplace=True)
plt.plot(log_data_diff)

# %%
test_stationarity(log_data_diff)
# Out:
# Test Statistic           -3.030060
# p                         0.032181
# No of Lags               12.000000
# No of Obs               110.000000
# Critical value (1%)      -3.491245
# Critical value (5%)      -2.888195
# Critical value (10%)     -2.580988
# dtype: float64

# %%
adftest(log_data_diff)
# Out:
# Reject Null Hypothesis
# Data is  Stationary

# %%
boxcox_diff=boxCox-boxCox.shift()
boxcox_diff.dropna(inplace=True)
plt.plot(boxcox_diff)

# %%
test_stationarity(boxcox_diff)
# Out:
# Test Statistic           -3.030060
# p                         0.032181
# No of Lags               12.000000
# No of Obs               110.000000
# Critical value (1%)      -3.491245
# Critical value (5%)      -2.888195
# Critical value (10%)     -2.580988
# dtype: float64

# %%
adftest(boxcox_diff)
# Out:
# Reject Null Hypothesis
# Data is  Stationary

# %% [markdown]
# ###We found that both log transform and boxcox transformations have resulted in stationarity

# %%
train_data=log_data[:100]
test_data=log_data[100:]
train_diff=log_data_diff[:99]
test_diff=log_data_diff[99:]

# %%
from statsmodels.tsa.arima.model import ARIMA
def eval_arima(X,arima_order):
  X=X.astype('float32')
  train_size=int(len(X)*0.70)
  train,test=X[:train_size],X[train_size:]
  history=[x for x in train]
  predictions=[]
  for i in range(len(test)):
    try:
      model=ARIMA(history,order=arima_order)
      model_fit=model.fit()
      yhat=model_fit.forecast()[0]
      predictions.append(yhat)
      history.append(test[i])
    except Exception as e:
      print(f'{e}')
      continue
  rmse=sqrt(mean_squared_error(test,predictions))
  return rmse


def evaluate_models(dataset,p_vals,d_vals,q_vals):
  dataset=dataset.astype('float32')
  best_score,best_cfg=float('inf'),None
  for p in p_vals:
    for d in d_vals:
      for q in q_vals:
        order=(p,d,q)
        try:
          rmse=eval_arima(dataset,order)
          if rmse<best_score:
            best_score=rmse
            best_cfg=order
        except Exception as e:
          print(f'{e}')
          continue
  print(f'Best RMSE of ARIMA is {best_score} with order {best_cfg}')

# %%
import warnings
p_vals=range(0,5)
d_vals=range(0,5)
q_vals=range(0,5)
warnings.filterwarnings("ignore")
evaluate_models(train_diff['Sales'],p_vals,d_vals,q_vals)
# Out:
# Best RMSE of ARIMA is 0.027738577745325475 with order (3, 0, 2)

# %%
boxcox_diff
# Out:
#                Sales
# Date
# 1986-02-28  0.093507
# 1986-03-31  0.085506
# 1986-04-30  0.078767
# 1986-05-31  0.041994
# 1986-06-30  0.040301
# ...              ...
# 1995-12-31 -0.010868
# 1996-01-31 -0.010987
# 1996-02-29  0.080813
# 1996-03-31  0.074768
# 1996-04-30  0.069564
#
# [123 rows x 1 columns]

# %%
model=ARIMA(train_diff,order=(3,0,2))
model_fit=model.fit()
yhat_ar=log_data_diff.copy()
yhat_ar['arima_forecast']=model_fit.predict(log_data_diff.index.min(),log_data_diff.index.max())
yhat_ar['arima_forecast']=yhat_ar['arima_forecast'].cumsum()
yhat_ar['arima_forecast']=yhat_ar['arima_forecast'].add(log_data.Sales[0])
yhat_ar['arima_forecast']=np.exp(yhat_ar['arima_forecast'])

# %%
yhat_ar
# Out:
#                Sales  arima_forecast
# Date
# 1986-02-28  0.093507     1750.947314
# 1986-03-31  0.085506     1855.509495
# 1986-04-30  0.078767     1950.089243
# 1986-05-31  0.041994     2017.343153
# 1986-06-30  0.040301     2072.638195
# ...              ...             ...
# 1995-12-31 -0.010868     5071.005576
# 1996-01-31 -0.010987     5118.126208
# 1996-02-29  0.080813     5165.684742
# 1996-03-31  0.074768     5213.685175
# 1996-04-30  0.069564     5262.131647
#
# [123 rows x 2 columns]

# %%
plt.figure(figsize=(15,5))
plt.plot(train['Sales'],label="Train")
plt.plot(test['Sales'],label="Test")
plt.plot(yhat_ar['arima_forecast'][test.index.min():],label="AR Forecast")
plt.legend(loc="best")
plt.show()

# %%
rmse_arima=sqrt(mean_squared_error(test,yhat_ar['arima_forecast'][test.index.min():]))
rmse_arima
# Out:
# 455.39207198635586

# %%
mape_arima=MAPE(yhat_ar['arima_forecast'][test.index.min():],test.Sales)
mape_arima
# Out:
# 8.565597462724616

# %%
model_resid=model_fit.resid
model_resid.mean()
# Out:
# 0.00022566856589238094

# %%
adftest(model_resid)
# Out:
# Reject Null Hypothesis
# Data is  Stationary

# %%
model_resid.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ###Sarima Seasonal order p=1,q=1,d=1 and m=12

# %%
train_data
# Out:
#                Sales
# Date
# 1986-01-31  7.458663
# 1986-02-28  7.552170
# 1986-03-31  7.637676
# 1986-04-30  7.716443
# 1986-05-31  7.758437
# ...              ...
# 1993-12-31  8.119399
# 1994-01-31  8.117312
# 1994-02-28  8.211211
# 1994-03-31  8.297045
# 1994-04-30  8.376090
#
# [100 rows x 1 columns]

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model=SARIMAX(train_data,order=(1,1,1),seasonal_order=(1,1,1,12))
model_fit=model.fit()
yhat_sarima=log_data_diff.copy()

# %%
yhat_sarima['sarima_forecast_log']=model_fit.predict(log_data_diff.index.min(),log_data_diff.index.max())
yhat_sarima['sarima_forecast']=np.exp(yhat_sarima['sarima_forecast_log'])
yhat_sarima['sarima_forecast']=np.exp(yhat_sarima['sarima_forecast_log'])

# %%
yhat_sarima
# Out:
#                Sales  sarima_forecast_log  sarima_forecast
# Date
# 1986-02-28  0.093507             7.458663      1734.827002
# 1986-03-31  0.085506             7.552170      1904.871668
# 1986-04-30  0.078767             7.637676      2074.916333
# 1986-05-31  0.041994             7.716443      2244.960999
# 1986-06-30  0.040301             7.758437      2341.242330
# ...              ...                  ...              ...
# 1995-12-31 -0.010868             8.348611      4224.309604
# 1996-01-31 -0.010987             8.347255      4218.585979
# 1996-02-29  0.080813             8.441465      4635.342798
# 1996-03-31  0.074768             8.527559      5052.096251
# 1996-04-30  0.069564             8.606824      5468.850169
#
# [123 rows x 3 columns]

# %%
plt.figure(figsize=(15,5))
plt.plot(train,label="Train")
plt.plot(test,label="Test")
plt.plot(yhat_sarima['sarima_forecast'][test.index.min():],label="Sarima Forecast")
plt.legend(loc="best")
plt.show()

# %%
rmse_sarima=sqrt(mean_squared_error(test,yhat_sarima['sarima_forecast'][test.index.min():]))
rmse_sarima
# Out:
# 204.64070023673034

# %%
mape_sarima=MAPE(yhat_sarima['sarima_forecast'][test.index.min():],test.Sales)
mape_sarima
# Out:
# 3.9126776954611278

# %%
model_resid=model_fit.resid
model_resid.mean()
# Out:
# 0.03703274203999538

# %%
adftest(model_resid)
# Out:
# Reject Null Hypothesis
# Data is  Stationary

# %%
Evaluation={"Models":pd.Series(["Simple_Exponential","Double_Exponential","Triple_Exponential_Add","Triple_Exponential_Mul_Add","Triple_Exponential_Add_Mul","Triple_Exponential_Mul_Mul","ARIMA","SARIMAX"]),
            "Test_RMSE":pd.Series([test_rmse_ses,test_rmse_des,test_rmse_texp_add_add,test_rmse_texp_mul_add,test_rmse_texp_add_mul,test_rmse_texp_mul_mul,rmse_arima,rmse_sarima]),

            "MAPE":pd.Series([mape_ses,mape_des,mape_texp_add_add,mape_texp_mul_add,mape_texp_add_mul,mape_texp_mul_mul,mape_arima,mape_sarima])
            }
table=pd.DataFrame(Evaluation)
table.sort_values(['MAPE'],inplace=True)
table
# Out:
#                        Models    Test_RMSE       MAPE
# 3  Triple_Exponential_Mul_Add    78.733258   1.487269
# 5  Triple_Exponential_Mul_Mul   101.651349   1.807823
# 7                     SARIMAX   204.640700   3.912678
# 4  Triple_Exponential_Add_Mul   291.559678   5.439767
# 0          Simple_Exponential   381.954224   6.619719
# 6                       ARIMA   455.392072   8.565597
# 2      Triple_Exponential_Add  1828.476772  35.695713
# 1          Double_Exponential  4549.832594  89.493161

# %%
sns.barplot(x="MAPE",y="Models",data=table)
# Out:
# <Axes: xlabel='MAPE', ylabel='Models'>

# %%
sns.barplot(x="Test_RMSE",y="Models",data=table)
# Out:
# <Axes: xlabel='Test_RMSE', ylabel='Models'>

# %% [markdown]
# ###Triple Exponential Smoothing with Multiplicative Seasonality and Additive Trend has the least RMSE and MAPE values.
