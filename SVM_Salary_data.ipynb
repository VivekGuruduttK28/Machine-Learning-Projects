# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset_train=pd.read_csv("/content/SalaryData_Train(1).csv")
dataset_test=pd.read_csv("/content/SalaryData_Test(1).csv")

# %%
dataset_train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
dataset_test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
dataset_train.shape
# Out:
# (30161, 14)

# %%
dataset_test.shape
# Out:
# (15060, 14)

# %%
dataset_test.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  15060.000000  15060.000000  15060.000000  15060.000000  15060.000000
# mean      38.768327     10.112749   1120.301594     89.041899     40.951594
# std       13.380676      2.558727   7703.181842    406.283245     12.062831
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       48.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   3770.000000     99.000000

# %%
dataset_test.isna().any()
# Out:
# age              False
# workclass        False
# education        False
# educationno      False
# maritalstatus    False
# occupation       False
# relationship     False
# race             False
# sex              False
# capitalgain      False
# capitalloss      False
# hoursperweek     False
# native           False
# Salary           False
# dtype: bool

# %%
dataset_train.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  30161.000000  30161.000000  30161.000000  30161.000000  30161.000000
# mean      38.438115     10.121316   1092.044064     88.302311     40.931269
# std       13.134830      2.550037   7406.466611    404.121321     11.980182
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
dataset_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
dataset_train.kurt()
# Out:
# <ipython-input-11-b11b149a5ab6>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset_train.kurt()
# age              -0.144760
# educationno       0.643605
# capitalgain     153.661174
# capitalloss      19.529284
# hoursperweek      3.167683
# dtype: float64

# %%
dataset_train.skew()
# Out:
# <ipython-input-12-f3a6d48224de>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset_train.skew()
# age              0.530180
# educationno     -0.305378
# capitalgain     11.902483
# capitalloss      4.528238
# hoursperweek     0.330856
# dtype: float64

# %%
dataset_train.isna().any()
# Out:
# age              False
# workclass        False
# education        False
# educationno      False
# maritalstatus    False
# occupation       False
# relationship     False
# race             False
# sex              False
# capitalgain      False
# capitalloss      False
# hoursperweek     False
# native           False
# Salary           False
# dtype: bool

# %%
sns.countplot(data=dataset_train,x='Salary')
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='count'>

# %%
sns.countplot(data=dataset_train,x='workclass')
# Out:
# <AxesSubplot:xlabel='workclass', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=dataset_train,x='education')
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=dataset_train,x='maritalstatus')
# Out:
# <AxesSubplot:xlabel='maritalstatus', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=dataset_train,x='occupation')
# Out:
# <AxesSubplot:xlabel='occupation', ylabel='count'>

# %%
dataset_train['native'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' Mexico',
#        ' Puerto-Rico', ' Honduras', ' England', ' Canada', ' Germany',
#        ' Iran', ' Philippines', ' Poland', ' Columbia', ' Cambodia',
#        ' Thailand', ' Ecuador', ' Laos', ' Taiwan', ' Haiti', ' Portugal',
#        ' Dominican-Republic', ' El-Salvador', ' France', ' Guatemala',
#        ' Italy', ' China', ' South', ' Japan', ' Yugoslavia', ' Peru',
#        ' Outlying-US(Guam-USVI-etc)', ' Scotland', ' Trinadad&Tobago',
#        ' Greece', ' Nicaragua', ' Vietnam', ' Hong', ' Ireland',
#        ' Hungary'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
dataset_train['Salary']=le.fit_transform(dataset_train['Salary'])
dataset_test['Salary']=le.fit_transform(dataset_test['Salary'])

# %%
dataset_train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
dataset_test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
sns.pairplot(data=dataset_train,hue='Salary')

# %%
le1=LabelEncoder()
dataset_train['workclass']=le1.fit_transform(dataset_train['workclass'])
dataset_train['education']=le1.fit_transform(dataset_train['education'])
dataset_train['maritalstatus']=le1.fit_transform(dataset_train['maritalstatus'])
dataset_train['occupation']=le1.fit_transform(dataset_train['occupation'])
dataset_train['relationship']=le1.fit_transform(dataset_train['relationship'])
dataset_train['native']=le1.fit_transform(dataset_train['native'])

# %%
dataset_train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship    race      sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
dataset_train=pd.get_dummies(dataset_train)

# %%
dataset_train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  capitalgain  capitalloss  hoursperweek  native  Salary  \
# ...

# %%
dataset_train.shape
# Out:
# (30161, 19)

# %%
dataset_train.corr()
# Out:
#                                age  workclass  education  educationno  \
# age                       1.000000   0.080537  -0.001091     0.043525
# workclass                 0.080537   1.000000   0.017864     0.037833
# education                -0.001091   0.017864   1.000000     0.345420
# educationno               0.043525   0.037833   0.345420     1.000000
# maritalstatus            -0.276363  -0.034235  -0.040704    -0.063419
# occupation               -0.005682   0.015572  -0.038213     0.087717
# relationship             -0.246452  -0.067414  -0.012732    -0.091935
# capitalgain               0.080152   0.035349   0.030582     0.124416
# capitalloss               0.060278   0.007244   0.014822     0.079691
# hoursperweek              0.101598   0.050723   0.059892     0.152522
# native                   -0.001548   0.007598   0.079715     0.092625
# Salary                    0.241991   0.018040   0.079013     0.335287
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(dataset_train.corr())
# Out:
# <AxesSubplot:>

# %%
le1=LabelEncoder()
dataset_test['workclass']=le1.fit_transform(dataset_test['workclass'])
dataset_test['education']=le1.fit_transform(dataset_test['education'])
dataset_test['maritalstatus']=le1.fit_transform(dataset_test['maritalstatus'])
dataset_test['occupation']=le1.fit_transform(dataset_test['occupation'])
dataset_test['relationship']=le1.fit_transform(dataset_test['relationship'])
dataset_test['native']=le1.fit_transform(dataset_test['native'])
dataset_test=pd.get_dummies(dataset_test)

# %%
dataset_test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  capitalgain  capitalloss  hoursperweek  native  Salary  \
# ...

# %%
dataset_test.shape
# Out:
# (15060, 19)

# %%
X_train=pd.concat([dataset_train.iloc[:,:11],dataset_train.iloc[:,12:]],axis=1)
X_test=pd.concat([dataset_test.iloc[:,:11],dataset_test.iloc[:,12:]],axis=1)
y_train=dataset_train['Salary'].values
y_test=dataset_test['Salary'].values

# %%
X_train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  capitalgain  capitalloss  hoursperweek  native  \
# ...

# %%
X_train.shape
# Out:
# (30161, 18)

# %%
y_train
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
X_train=X_train.values
X_test=X_test.values

# %%
from sklearn.svm import SVC
classifier=SVC(kernel='rbf',random_state=0)
classifier.fit(X_train,y_train)
# Out:
# SVC(random_state=0)

# %%
y_pred=classifier.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[10997,   363],
#        [ 2703,   997]])

# %%
from sklearn.metrics import accuracy_score
accscore=accuracy_score(y_test,y_pred)
accscore*100
# Out:
# 79.64143426294821

# %% [markdown]
# ###The accuracy is 79.641%
